# %%
import itertools
import geopandas
import numpy as np
import pandas
import seaborn as sns
import sys
sys.path.append("../src")
import utils
import make_data as md

# %%
lon, lat = -97.385551, 41.964567

# %%
lon_m, lat_m, epsg_utm = utils.convert_degree_to_meters(lon, lat)

# %% [markdown]
# #### Want a field that is approx 10 acres (ie 40468 square meters)

# %% [markdown]
# Propose a field that is 100 meters wide by 400 meters long

# %% [markdown]
# `lon_m` and `lat_m` to be designated as the top right-corner of the field

# %%
lon_m_top_left = lon_m - 100
lat_m_top_left = lat_m

lon_m_bottom_left = lon_m_top_left
lat_m_bottom_left = lat_m - 400

lon_m_bottom_right = lon_m
lat_m_bottom_right = lat_m_bottom_left

# %%
list_tuple_coords = [
    (lon_m, lat_m),
    (lon_m_top_left, lat_m_top_left),
    (lon_m_bottom_left, lat_m_bottom_left),
    (lon_m_bottom_right, lat_m_bottom_right),
]

polygon_utm = utils.create_polygon_from_list_tuple(list_tuple_coords)

# %%
polygon_utm.area
# Out:
# 40000.0

# %%
list_tuple_coords_degrees = [
    utils.convert_meters_to_degree(lon, lat, epsg_utm) for (lon, lat) in list_tuple_coords
]

# %%
list_tuple_coords_degrees
# Out:
# [(-97.38555100000002, 41.964566999999995),
#  (-97.38675732371843, 41.96458396139896),
#  (-97.3868481872366, 41.96098270170655),
#  (-97.38564193139067, 41.96096574243743)]

# %%
polygon = utils.create_polygon_from_list_tuple(list_tuple_coords_degrees)

# %%
polygon
# Out:
# <POLYGON ((-97.386 41.965, -97.387 41.965, -97.387 41.961, -97.386 41.961, -...>

# %% [markdown]
# ## Now that I have the boundary conditions of a field, I will populate that area with dummy data
# * assume 2 treatments and a control, that is T1 | Control | T2
# * Each treatment is comprised of 3 harvester passes

# %% [markdown]
# want each harvester pass to be 5 meters

# %%
import pandas as pd

# %%
pass_width = 5 # meters
buffer = 1 # meter
pass_length = 100 # meters
points_per_pass = 100

# %%
tnames = ["T1", "Control", "T2"]
effect_size = [5, 0, 1]
treatment_sds_pct= [0.2, 0.2, 0.15]
passes_per_treatment = 3

# %%
df_meta = md.make_df_meta(3, tnames, effect_size, treatment_sds_pct)

# %%
df_block
# Out:
#     treatmentname  x_lon      y_lat     value
# 0         Control     24   1.926042  0.000000
# 1         Control     24   2.778537  0.000000
# 2         Control     24   4.162395  0.000000
# 3         Control     24   4.904147  0.000000
# 4         Control     24   6.477959  0.000000
# ..            ...    ...        ...       ...
# 895            T2     54  96.214426  0.907803
# 896            T2     54  96.601772  1.132229
# 897            T2     54  96.911445  1.126817
# 898            T2     54  98.808585  1.170642
# 899            T2     54  99.976244  0.739994
#
# [900 rows x 4 columns]

# %%
lon
# Out:
# -97.385551

# %%
df_block = df_block.assign(
    longitude_m=lambda x: x.x_lon + lon_m,
    latitude_m=lambda x: x.y_lat + lat_m
)

# %%
sns.scatterplot(
    data=df_block,
    x="longitude_m",
    y="latitude_m",
    hue="treatmentname"
);

# %%
df_block[['longitude', 'latitude']] = df_block.apply(
    lambda row: utils.convert_meters_to_degree(row['longitude_m'], row['latitude_m'], epsg_utm), 
    axis=1, 
    result_type='expand'
)

# %%
sns.scatterplot(
    data=df_block,
    x="longitude",
    y="latitude",
    hue="treatmentname"
);

# %%
df_block.head()
# Out:
#   treatmentname  x_lon     y_lat  value  longitude   latitude    longitude_m  \
# 0       Control     24  1.926042    0.0 -97.385261  41.964580  633804.881693
# 1       Control     24  2.778537    0.0 -97.385261  41.964588  633804.881693
# 2       Control     24  4.162395    0.0 -97.385261  41.964600  633804.881693
# 3       Control     24  4.904147    0.0 -97.385260  41.964607  633804.881693
# 4       Control     24  6.477959    0.0 -97.385260  41.964621  633804.881693
#
#      latitude_m
# 0  4.647105e+06
# 1  4.647105e+06
# 2  4.647107e+06
# 3  4.647108e+06
# 4  4.647109e+06
